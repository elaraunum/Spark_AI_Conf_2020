# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 1200px">
# </div>

# %% [markdown]
# -sandbox
# # Introduction to OpenAI gym
#
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) In this lesson you learn:<br>
#  - OpenAI gym
#  - Run your first RL code
#
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Library Requirements
#
# <img alt="Caution" title="Caution" style="vertical-align: text-bottom; position: relative; height:1.3em; top:0.0em" src="https://files.training.databricks.com/static/images/icon-warning.svg"/> Additional libraries must be attached to your cluster for this lesson to work.
#
# We will use the PyPI library **`gym==0.15.4`**.
# * This library is used to develop and compare reinforcement learning algorithms
#
# For more information on how to create and/or install PyPI libraries see:
# * <a href="https://www.databricks.training/step-by-step/creating-pypi-libraries" target="_blank">Creating a Workspace Library</a>
# * <a href="https://www.databricks.training/step-by-step/installing-libraries-from-pypi" target="_blank">Installing a Cluster Library</a> (recommended)

# %% [markdown]
# ### What is OpenAI gym?
#
# OpenAI gym provides different environments for RL problems. The user can either used already-built environment or build environment on top of those environments. This library does not care about what algorithms you are using for the agent. To write your own environment, you need to define 4 methods:
# 0. initialize the class i.e. init
# 0. reset(): how to reset the environment?
# 0. step(): how does the environment respond to an action?
# 0. render():how to render the results?
#
# <br><br>
# In the following demo, we will focus on CartPole-v0 environment. For details see [here](https://github.com/openai/gym/wiki/CartPole-v0).

# %%
# import required library
import gym

# import an environment  
env = gym.make('CartPole-v0')

# reset the environment. In this case all states variables are sampled uniformly from [-0.05, +0.05] 
env.reset()

# run for 100 time steps
for i in range(100):
  print(f"Observation, reward, done, info are: {env.step(0)}") # push cart to left (value is 0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Observation, reward, done, info are: (array([-0.03457677, -0.19781545,  0.04705852,  0.29942973]), 1.0, False, {})
# Observation, reward, done, info are: (array([-0.03853307, -0.39357549,  0.05304711,  0.60657481]), 1.0, False, {})
# Observation, reward, done, info are: (array([-0.04640458, -0.58939747,  0.06517861,  0.91548313]), 1.0, False, {})
# Observation, reward, done, info are: (array([-0.05819253, -0.78533745,  0.08348827,  1.22791797]), 1.0, False, {})
# Observation, reward, done, info are: (array([-0.07389928, -0.98142874,  0.10804663,  1.54554744]), 1.0, False, {})
# Observation, reward, done, info are: (array([-0.09352786, -1.17766992,  0.13895758,  1.86989662]), 1.0, False, {})
# Observation, reward, done, info are: (array([-0.11708126, -1.37401106,  0.17635551,  2.20229168]), 1.0, False, {})
# Observation, reward, done, info are: (array([-0.14456148, -1.57033776,  0.22040134,  2.54379427]), 1.0, True, {})
# /databricks/python/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: <span class="ansi-yellow-fg">WARN: You are calling &#39;step()&#39; even though this environment has already returned done = True. You should always call &#39;reset()&#39; once you receive &#39;done = True&#39; -- any further steps are undefined behavior.</span>
#   warnings.warn(colorize(&#39;%s: %s&#39;%(&#39;WARN&#39;, msg % args), &#39;yellow&#39;))
# Observation, reward, done, info are: (array([-0.17596823, -1.76645319,  0.27127723,  2.89512595]), 0.0, True, {})
# Observation, reward, done, info are: (array([-0.2112973 , -1.96205866,  0.32917975,  3.25658493]), 0.0, True, {})
# Observation, reward, done, info are: (array([-0.25053847, -2.15673449,  0.39431145,  3.6279603 ]), 0.0, True, {})
# Observation, reward, done, info are: (array([-0.29367316, -2.34992377,  0.46687065,  4.00845332]), 0.0, True, {})
# Observation, reward, done, info are: (array([-0.34067164, -2.5409231 ,  0.54703972,  4.39661917]), 0.0, True, {})
# Observation, reward, done, info are: (array([-0.3914901 , -2.72888547,  0.6349721 ,  4.79034556]), 0.0, True, {})
# Observation, reward, done, info are: (array([-0.44606781, -2.91284096,  0.73077901,  5.18688375]), 0.0, True, {})
# Observation, reward, done, info are: (array([-0.50432463, -3.09174042,  0.83451669,  5.5829415 ]), 0.0, True, {})
# Observation, reward, done, info are: (array([-0.56615943, -3.26452492,  0.94617552,  5.97483377]), 0.0, True, {})
# Observation, reward, done, info are: (array([-0.63144993, -3.43022029,  1.06567219,  6.35866756]), 0.0, True, {})
# Observation, reward, done, info are: (array([-0.70005434, -3.58805119,  1.19284555,  6.73051656]), 0.0, True, {})
# Observation, reward, done, info are: (array([-0.77181536, -3.73756571,  1.32745588,  7.08652688]), 0.0, True, {})
# Observation, reward, done, info are: (array([-0.84656668, -3.87875933,  1.46918641,  7.42289527]), 0.0, True, {})
# Observation, reward, done, info are: (array([-0.92414186, -4.01218769,  1.61764432,  7.73568035]), 0.0, True, {})
# Observation, reward, done, info are: (array([-1.00438562, -4.1390587 ,  1.77235793,  8.02044557]), 0.0, True, {})
# Observation, reward, done, info are: (array([-1.08716679, -4.26129401,  1.93276684,  8.2717864 ]), 0.0, True, {})
# Observation, reward, done, info are: (array([-1.17239267, -4.38154309,  2.09820257,  8.48286195]), 0.0, True, {})
# Observation, reward, done, info are: (array([-1.26002353, -4.50312109,  2.2678598 ,  8.64512771]), 0.0, True, {})
# Observation, reward, done, info are: (array([-1.35008595, -4.62982719,  2.44076236,  8.74853445]), 0.0, True, {})
# Observation, reward, done, info are: (array([-1.4426825 , -4.76559842,  2.61573305,  8.78246472]), 0.0, True, {})
# Observation, reward, done, info are: (array([-1.53799447, -4.91398604,  2.79138234,  8.7375309 ]), 0.0, True, {})
# Observation, reward, done, info are: (array([-1.63627419, -5.07752303,  2.96613296,  8.60798536]), 0.0, True, {})
# Observation, reward, done, info are: (array([-1.73782465, -5.25716041,  3.13829267,  8.39398728]), 0.0, True, {})
# Observation, reward, done, info are: (array([-1.84296786, -5.45200804,  3.30617241,  8.10268763]), 0.0, True, {})
# Observation, reward, done, info are: (array([-1.95200802, -5.65953449,  3.46822617,  7.74743602]), 0.0, True, {})
# Observation, reward, done, info are: (array([-2.06519871, -5.87617176,  3.62317489,  7.34532945]), 0.0, True, {})
# Observation, reward, done, info are: (array([-2.18272214, -6.09807837,  3.77008147,  6.91415244]), 0.0, True, {})
# Observation, reward, done, info are: (array([-2.30468371, -6.32178341,  3.90836452,  6.4698649 ]), 0.0, True, {})
# Observation, reward, done, info are: (array([-2.43111938, -6.54455848,  4.03776182,  6.02523497]), 0.0, True, {})
# Observation, reward, done, info are: (array([-2.56201055, -6.7645196 ,  4.15826652,  5.58955503]), 0.0, True, {})
# Observation, reward, done, info are: (array([-2.69730094, -6.98054845,  4.27005762,  5.16903775]), 0.0, True, {})
# Observation, reward, done, info are: (array([-2.83691191, -7.19213179,  4.37343838,  4.76748182]), 0.0, True, {})
# Observation, reward, done, info are: (array([-2.98075454, -7.3991883 ,  4.46878801,  4.38694053]), 0.0, True, {})
# Observation, reward, done, info are: (array([-3.12873831, -7.60191789,  4.55652682,  4.02827346]), 0.0, True, {})
# Observation, reward, done, info are: (array([-3.28077667, -7.80068494,  4.63709229,  3.69155484]), 0.0, True, {})
# Observation, reward, done, info are: (array([-3.43679037, -7.9959345 ,  4.71092339,  3.37635624]), 0.0, True, {})
# Observation, reward, done, info are: (array([-3.59670906, -8.18813572,  4.77845051,  3.08193403]), 0.0, True, {})
# Observation, reward, done, info are: (array([-3.76047177, -8.37774598,  4.8400892 ,  2.80735057]), 0.0, True, {})
# Observation, reward, done, info are: (array([-3.92802669, -8.5651898 ,  4.89623621,  2.55155192]), 0.0, True, {})
# Observation, reward, done, info are: (array([-4.09933049, -8.75084798,  4.94726725,  2.31341769]), 0.0, True, {})
# Observation, reward, done, info are: (array([-4.27434745, -8.93505351,  4.9935356 ,  2.09179388]), 0.0, True, {})
# Observation, reward, done, info are: (array([-4.45304852, -9.11809181,  5.03537148,  1.88551493]), 0.0, True, {})
# Observation, reward, done, info are: (array([-4.63541035, -9.30020346,  5.07308177,  1.69341911]), 0.0, True, {})
# Observation, reward, done, info are: (array([-4.82141442, -9.4815884 ,  5.10695016,  1.51435951]), 0.0, True, {})
# Observation, reward, done, info are: (array([-5.01104619, -9.66241065,  5.13723735,  1.34721186]), 0.0, True, {})
# Observation, reward, done, info are: (array([-5.2042944 , -9.84280316,  5.16418158,  1.19088009]), 0.0, True, {})
# Observation, reward, done, info are: (array([ -5.40115047, -10.02287245,   5.18799919,   1.0443    ]), 0.0, True, {})
# Observation, reward, done, info are: (array([ -5.60160791, -10.2027028 ,   5.20888519,   0.90644139]), 0.0, True, {})
# Observation, reward, done, info are: (array([ -5.80566197, -10.38236008,   5.22701401,   0.77630885]), 0.0, True, {})
# Observation, reward, done, info are: (array([ -6.01330917, -10.56189506,   5.24254019,   0.65294147]), 0.0, True, {})
# Observation, reward, done, info are: (array([ -6.22454707, -10.74134622,   5.25559902,   0.5354116 ]), 0.0, True, {})
# Observation, reward, done, info are: (array([ -6.439374  , -10.92074224,   5.26630725,   0.42282287]), 0.0, True, {})
# Observation, reward, done, info are: (array([ -6.65778884, -11.10010403,   5.27476371,   0.31430751]), 0.0, True, {})
# Observation, reward, done, info are: (array([ -6.87979092, -11.27944649,   5.28104986,   0.20902328]), 0.0, True, {})
# Observation, reward, done, info are: (array([ -7.10537985, -11.45878007,   5.28523033,   0.10614998]), 0.0, True, {})
# Observation, re

# %% [markdown]
# ### Observations
#
# 0. `step()` function runs agent-environment loop
# 0. It carries an action, watches the observation
# 0. Observation, reward, done, info are the 4 elements of observation array

# %%
# reset the environment  
env.reset()
# Run for 1000 time steps
for i in range(100):
  print(f"Random action is: {env.action_space.sample()}")
  print(f"Observation, reward, done, info are: {env.step(env.action_space.sample())}") # take a random action
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Random action is: 1
# Observation, reward, done, info are: (array([ 0.00330982,  0.16192818,  0.0363125 , -0.32846327]), 1.0, False, {})
# Random action is: 0
# Observation, reward, done, info are: (array([ 0.00654838, -0.0336914 ,  0.02974323, -0.02455381]), 1.0, False, {})
# Random action is: 0
# Observation, reward, done, info are: (array([ 0.00587455, -0.22922699,  0.02925215,  0.27736307]), 1.0, False, {})
# Random action is: 0
# Observation, reward, done, info are: (array([ 0.00129001, -0.42475378,  0.03479942,  0.5791267 ]), 1.0, False, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.00720506, -0.6203457 ,  0.04638195,  0.88256591]), 1.0, False, {})
# Random action is: 0
# Observation, reward, done, info are: (array([-0.01961198, -0.81606586,  0.06403327,  1.18946182]), 1.0, False, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.03593329, -1.01195662,  0.0878225 ,  1.50150868]), 1.0, False, {})
# Random action is: 0
# Observation, reward, done, info are: (array([-0.05617242, -0.81800396,  0.11785268,  1.23748755]), 1.0, False, {})
# Random action is: 0
# Observation, reward, done, info are: (array([-0.0725325 , -0.62457658,  0.14260243,  0.98392761]), 1.0, False, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.08502404, -0.43162308,  0.16228098,  0.73921838]), 1.0, False, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.0936565 , -0.23906949,  0.17706535,  0.50168433]), 1.0, False, {})
# Random action is: 0
# Observation, reward, done, info are: (array([-0.09843789, -0.04682735,  0.18709904,  0.26961533]), 1.0, False, {})
# Random action is: 0
# Observation, reward, done, info are: (array([-0.09937443, -0.24405787,  0.19249134,  0.61498476]), 1.0, False, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.10425559, -0.05207236,  0.20479104,  0.38856888]), 1.0, False, {})
# Random action is: 0
# Observation, reward, done, info are: (array([-0.10529704, -0.24942273,  0.21256241,  0.73819713]), 1.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.11028549, -0.44674738,  0.22732636,  1.0895463 ]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.11922044, -0.64402415,  0.24911728,  1.44410808]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.13210092, -0.84119423,  0.27799945,  1.80321865]), 0.0, True, {})
# Random action is: 0
# Observation, reward, done, info are: (array([-0.14892481, -1.03814492,  0.31406382,  2.16798534]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.16968771, -0.84715383,  0.35742352,  1.98633622]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.18663078, -0.65708787,  0.39715025,  1.82211452]), 0.0, True, {})
# Random action is: 0
# Observation, reward, done, info are: (array([-0.19977254, -0.4678995 ,  0.43359254,  1.67413644]), 0.0, True, {})
# Random action is: 0
# Observation, reward, done, info are: (array([-0.20913053, -0.66479737,  0.46707527,  2.0656718 ]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.22242648, -0.47636238,  0.5083887 ,  1.94567586]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.23195373, -0.28879273,  0.54730222,  1.84301478]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.23772958, -0.48468168,  0.58416252,  2.24692171]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.24742321, -0.29760449,  0.62910095,  2.17498053]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.2533753 , -0.11130977,  0.67260056,  2.12203064]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.2556015 , -0.30517753,  0.71504117,  2.53266542]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.26170505, -0.11891129,  0.76569448,  2.51446105]), 0.0, True, {})
# Random action is: 0
# Observation, reward, done, info are: (array([-0.26408328,  0.06679394,  0.8159837 ,  2.51740148]), 0.0, True, {})
# Random action is: 0
# Observation, reward, done, info are: (array([-0.2627474 , -0.12359072,  0.86633173,  2.92721476]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.26521921, -0.31143989,  0.92487603,  3.33371453]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.27144801, -0.49617736,  0.99155032,  3.73528664]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.28137156, -0.30598044,  1.06625605,  3.82515935]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.28749117, -0.11513239,  1.14275924,  3.94414064]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.28979381,  0.0767596 ,  1.22164205,  4.09213917]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.28825862,  0.27012965,  1.30348484,  4.26917113]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.28285603,  0.46545297,  1.38886826,  4.47534071]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.27354697,  0.66324206,  1.47837507,  4.71081091]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.26028213,  0.50018933,  1.57259129,  5.02612831]), 0.0, True, {})
# Random action is: 0
# Observation, reward, done, info are: (array([-0.25027834,  0.34136049,  1.67311386,  5.3197002 ]), 0.0, True, {})
# Random action is: 0
# Observation, reward, done, info are: (array([-0.24345113,  0.55027709,  1.77950786,  5.64417045]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.23244559,  0.76376114,  1.89239127,  5.99814097]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.21717037,  0.98210426,  2.01235409,  6.3805892 ]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.19752828,  0.83710476,  2.13996587,  6.55344286]), 0.0, True, {})
# Random action is: 0
# Observation, reward, done, info are: (array([-0.18078619,  1.06233805,  2.27103473,  6.98317179]), 0.0, True, {})
# Random action is: 0
# Observation, reward, done, info are: (array([-0.15953942,  1.29111856,  2.41069817,  7.42912948]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.13371705,  1.14386987,  2.55928076,  7.46092792]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.11083966,  0.98863751,  2.70849931,  7.4281415 ]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.09106691,  1.20897498,  2.85706214,  7.85151877]), 0.0, True, {})
# Random action is: 0
# Observation, reward, done, info are: (array([-0.06688741,  1.42360584,  3.01409252,  8.24304855]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.03841529,  1.23894032,  3.17895349,  8.00568227]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([-0.01363648,  1.04096772,  3.33906714,  7.69794907]), 0.0, True, {})
# Random action is: 1
# Observation, reward, done, info are: (array([7.18287120e-03, 8.32331816e-01, 3.49302612e+00, 7.33339652e+00]), 0.0, True, {})
# Random action is: 0
# Observation, reward, done, info are: (array([0.02382951, 0.61638566, 3.63969405, 6.92806742]), 0.0, True, {})
# Random action is: 0
# Observation, reward, done, info are: (array([0.03615722, 0.7803773 , 3.7782554 , 7.00370425]), 0.0, True, {})
# Random action is

# %% [markdown]
# To properly write this, we need to define an episode and inside each episode we move through time steps. The following cell shows the result.

# %%
# Move through episodes 
for i_episode in range(100):
  #reset the environment for each episode
    observation = env.reset()
    print(f"Initial observation is: {observation}") # show initial observation
    for i in range(100):
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        print(f"Random action is: {action}")
        print(f"Observation, reward, done, info are: {observation}") # take a random action
        if done:
            print("Episode finished after {} timesteps".format(i+1))
            break
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Initial observation is: [ 0.02846082 -0.00242783 -0.02747584  0.01897546]
# Random action is: 1
# Observation, reward, done, info are: [ 0.02841227  0.19307716 -0.02709633 -0.28224822]
# Random action is: 0
# Observation, reward, done, info are: [ 0.03227381 -0.00164803 -0.03274129  0.001767  ]
# Random action is: 1
# Observation, reward, done, info are: [ 0.03224085  0.19392781 -0.03270595 -0.30106375]
# Random action is: 0
# Observation, reward, done, info are: [ 0.03611941 -0.00071308 -0.03872723 -0.01887238]
# Random action is: 0
# Observation, reward, done, info are: [ 0.03610514 -0.19525886 -0.03910468  0.26134452]
# Random action is: 0
# Observation, reward, done, info are: [ 0.03219997 -0.38980141 -0.03387779  0.54144141]
# Random action is: 0
# Observation, reward, done, info are: [ 0.02440394 -0.58443123 -0.02304896  0.82326045]
# Random action is: 0
# Observation, reward, done, info are: [ 0.01271531 -0.77923041 -0.00658375  1.10860582]
# Random action is: 0
# Observation, reward, done, info are: [-0.00286929 -0.97426522  0.01558837  1.39921608]
# Random action is: 0
# Observation, reward, done, info are: [-0.0223546  -1.16957745  0.04357269  1.69673163]
# Random action is: 1
# Observation, reward, done, info are: [-0.04574615 -0.97498427  0.07750732  1.41792523]
# Random action is: 0
# Observation, reward, done, info are: [-0.06524583 -1.17097549  0.10586583  1.7337938 ]
# Random action is: 1
# Observation, reward, done, info are: [-0.08866534 -0.97720891  0.1405417   1.47583759]
# Random action is: 0
# Observation, reward, done, info are: [-0.10820952 -1.17374016  0.17005846  1.80891121]
# Random action is: 0
# Observation, reward, done, info are: [-0.13168432 -1.37030202  0.20623668  2.14925742]
# Random action is: 0
# Observation, reward, done, info are: [-0.15909036 -1.56677285  0.24922183  2.49792306]
# Episode finished after 16 timesteps
# Initial observation is: [-0.01388183  0.04232126  0.04900351  0.04678026]
# Random action is: 0
# Observation, reward, done, info are: [-0.0130354  -0.15346787  0.04993912  0.35451268]
# Random action is: 0
# Observation, reward, done, info are: [-0.01610476 -0.34926301  0.05702937  0.66251524]
# Random action is: 1
# Observation, reward, done, info are: [-0.02309002 -0.15497895  0.07027967  0.38832048]
# Random action is: 0
# Observation, reward, done, info are: [-0.0261896  -0.35102444  0.07804608  0.70230798]
# Random action is: 1
# Observation, reward, done, info are: [-0.03321009 -0.15706599  0.09209224  0.43517821]
# Random action is: 0
# Observation, reward, done, info are: [-0.03635141 -0.35336277  0.10079581  0.75541253]
# Random action is: 1
# Observation, reward, done, info are: [-0.04341866 -0.15976402  0.11590406  0.49607216]
# Random action is: 1
# Observation, reward, done, info are: [-0.04661394  0.03354914  0.1258255   0.24204748]
# Random action is: 1
# Observation, reward, done, info are: [-0.04594296  0.22667019  0.13066645 -0.00844882]
# Random action is: 1
# Observation, reward, done, info are: [-0.04140956  0.41969968  0.13049747 -0.25721806]
# Random action is: 0
# Observation, reward, done, info are: [-0.03301556  0.22297951  0.12535311  0.07361066]
# Random action is: 1
# Observation, reward, done, info are: [-0.02855597  0.41610227  0.12682533 -0.17704311]
# Random action is: 0
# Observation, reward, done, info are: [-0.02023393  0.21941501  0.12328446  0.15280498]
# Random action is: 1
# Observation, reward, done, info are: [-0.01584563  0.41257581  0.12634056 -0.09858323]
# Random action is: 1
# Observation, reward, done, info are: [-0.00759411  0.60568193  0.1243689  -0.34888833]
# Random action is: 1
# Observation, reward, done, info are: [ 0.00451953  0.79883583  0.11739113 -0.59991107]
# Random action is: 1
# Observation, reward, done, info are: [ 0.02049624  0.99213675  0.10539291 -0.8534331 ]
# Random action is: 0
# Observation, reward, done, info are: [ 0.04033898  0.79574826  0.08832425 -0.52955673]
# Random action is: 1
# Observation, reward, done, info are: [ 0.05625394  0.9895239   0.07773311 -0.79315359]
# Random action is: 0
# Observation, reward, done, info are: [ 0.07604442  0.79342581  0.06187004 -0.47706417]
# Random action is: 1
# Observation, reward, done, info are: [ 0.09191294  0.98762213  0.05232876 -0.7496231 ]
# Random action is: 0
# Observation, reward, done, info are: [ 0.11166538  0.79181894  0.0373363  -0.44094272]
# Random action is: 1
# Observation, reward, done, info are: [ 0.12750176  0.98639318  0.02851744 -0.72162635]
# Random action is: 1
# Observation, reward, done, info are: [ 0.14722962  1.18110927  0.01408492 -1.00519874]
# Random action is: 1
# Observation, reward, done, info are: [ 0.17085181  1.37604031 -0.00601906 -1.29342546]
# Random action is: 1
# Observation, reward, done, info are: [ 0.19837261  1.57123824 -0.03188757 -1.58798665]
# Random action is: 0
# Observation, reward, done, info are: [ 0.22979738  1.37650934 -0.0636473  -1.30541514]
# Random action is: 0
# Observation, reward, done, info are: [ 0.25732757  1.18224948 -0.0897556  -1.03331504]
# Random action is: 0
# Observation, reward, done, info are: [ 0.28097256  0.98842842 -0.1104219  -0.77010648]
# Random action is: 0
# Observation, reward, done, info are: [ 0.30074112  0.79498536 -0.12582403 -0.51410719]
# Random action is: 0
# Observation, reward, done, info are: [ 0.31664083  0.60183913 -0.13610618 -0.26357293]
# Random action is: 0
# Observation, reward, done, info are: [ 0.32867761  0.40889585 -0.14137764 -0.01672634]
# Random action is: 1
# Observation, reward, done, info are: [ 0.33685553  0.60573245 -0.14171216 -0.35046213]
# Random action is: 0
# Observation, reward, done, info are: [ 0.34897018  0.41288033 -0.14872141 -0.10560785]
# Random action is: 1
# Observation, reward, done, info are: [ 0.35722779  0.60978591 -0.15083356 -0.44126895]
# Random action is: 0
# Observation, reward, done, info are: [ 0.36942351  0.41708429 -0.15965894 -0.19967548]
# Random action is: 1
# Observation, reward, done, info are: [ 0.37776519  0.61408675 -0.16365245 -0.53816139]
# Random action is: 1
# Observation, reward, done, info are: [ 0.39004693  0.81108539 -0.17441568 -0.87761047]
# Random action is: 1
# Observation, reward, done, info are: [ 0.40626863  1.0080938  -0.19196789 -1.21965823]
# Random action is: 0
# Observation, reward, done, info are: [ 0.42643051  0.81589285 -0.21636105 -0.99274525]
# Episode finished after 40 timesteps
# Initial observation is: [-0.02683576  0.04779563 -0.00463359  0.03579705]
# Random action is: 0
# Observation, reward, done, info are: [-0.02587984 -0.14725957 -0.00391764  0.32701444]
# Random action is: 0
# Observation, reward, done, info are: [-0.02882503 -0.34232553  0.00262264  0.61845935]
# Random action is: 0
# Observation, reward, done, info are: [-0.03567155 -0.53748402  0.01499183  0.91196713]
# Random action is: 0
# Observation, reward, done, info are: [-0.04642123 -0.73280556  0.03323117  1.20932396]
# Random action is: 0
# Observation, reward, done, info are: [-0.06107734 -0.92834055  0.05741765  1.51223267]
# Random action is: 1
# Observation, reward, done, info are: [-0.07964415 -0.73395905  0.08766231  1.23801243]
# Random action is: 0
# Observation, reward, done, info are: [-0.09432333 -0.93009086  0.11242255  1.55682018]
# Random action is: 0
# Observation, reward, done, info are: [-0.11292515 -1.12636554  0.14355896  1.8823563 ]
# Random action is: 0
# Observation, reward, done, info are: [-0.13545246 -1.32272953  0.18120608  2.21593382]
# Random action is: 1
# Observation, reward, done, info are: [-0.16190705 -1.12974509  0.22552476  1.98418027]
# Episode finished after 10 timesteps
# Initial observation is: [ 0.04406674 -0.03307985  0.03947485 -0.04397967]
# Random action is: 1
# Observation, reward, done, info are: [ 0.04340514  0.16145447  0.03859526 -0.32395123]
# Random action is: 0
# Observation, reward, done, info are: [ 0.04663423 -0.03419518  0.03211623 -0.01

# %% [markdown]
# ### Spaces
#
# 0. Action space
# 0. Observation space
# 0. Create a space, sampling from space, etc.

# %%
# Print action and observation space
print(env.action_space)
print(env.observation_space)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Discrete(2)
# Box(4,)
# </div>

# %%
from gym import spaces
# Set with 8 elements {0, 1, 2, ..., 7}
space = spaces.Discrete(8) #7 different actions
x = space.sample()
assert space.contains(x), f"{x} does not belong to the space"
assert space.n == 8, f"The space must have 8 elements"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Available Environments
# [Click here to see all available environments](https://gym.openai.com/envs/#classic_control)

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
